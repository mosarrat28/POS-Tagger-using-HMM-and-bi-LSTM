# %%
from io import BytesIO
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load text
filename = '/content/drive/MyDrive/Colab Notebooks/data/newdataLDc.txt'
file = open(filename, 'rt')
text = file.read()
file.close()

# %%
file1=open('/content/drive/MyDrive/Colab Notebooks/data/newdatamodified.txt', 'w')
#words = text.split()
#print(words[:100])
#word='\n'.join(words)
#print(word[:100])
word = text.replace('\PU </sentence>','.\n')
word = word.replace('\PU','.')
word = word.replace('<sentence number="','s')
word1=word.replace('">','\n')
word1=word1.replace('\t','\n')
word1=word1.replace(' ','\n')
word1=word1.replace(' ','\n')

print(word1[:300])
file1.writelines(word1)
file1.close()
# Out:
# s1
#
#
# রপ্তানি\JJ.n.n
# দ্রব্য\NC.0.0.n.n
# -.
# তাজা\JJ.n.n
# ও\CCD.n
# শুকনা\JJ.n.n
# ফল\NC.0.0.n.n
# ,.
# আফিম\NC.0.0.n.n
# ,.
# পশুচর্ম\NC.0.0.n.n
# ও\CCD.n
# পশম\NC.0.0.n.n
# এবং\CCD.n
# কার্পেট\NC.0.0.n.n
# ৷.
#
# s2
#
#
# রাজা\NP.0.0.n.n
# মহানন্দ\NP.0.0.n.n
# রাজধানীতে\NC.0.loc.n.n
# তৈরি\NC.0.0.n.n
# করেছিল\VM.3.pst.pft.dcl.fin.n.n.n
# শি
